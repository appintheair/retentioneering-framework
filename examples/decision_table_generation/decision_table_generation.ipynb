# %%
import pandas as pd
path = '../../example_datasets/train.csv'
df = pd.read_csv(path)

from retentioneering import analysis

settings = {}

desc = analysis.get_desc_table(df, settings, plot=True)

desc.to_csv('./desc_table.csv')
