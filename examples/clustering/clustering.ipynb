# %%
import pandas as pd
from retentioneering import analysis

# %%
settings = {}

# %%
df = pd.read_csv('../../example_datasets/train.csv')

# %%
# we can build frequency of events for each user
countmap = analysis.calculate.calculate_frequency_map(df, settings=settings, make_plot=False)

# %%
# and cluster users based on this dataframe
users_clusters = analysis.cluster.cluster_users(countmap, n_clusters=5)

# %%
# now we can visualize target events in each cluster
cluster_stats = analysis.cluster.calculate_cluster_stats(df, users_clusters, settings, target_events=('lost', 'passed'), 
                                         plot_count=4, figsize=(12, 6))
