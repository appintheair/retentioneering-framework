# %%
import pandas as pd
from retentioneering import analysis

# %%
settings = {}
df = pd.read_csv('../../example_datasets/train.csv')

# %%
# for our clickstream we could calculate count of all events and plot histogram
event_counts = analysis.calculate.calculate_frequency_hist(df, settings)

# %%
# Also for our clickstream we could calculate count of all events for every user and plot heatmap
user_event_counts = analysis.calculate.calculate_frequency_map(df, settings)
